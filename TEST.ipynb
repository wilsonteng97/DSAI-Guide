# %% [markdown]
# # <div class="alert alert-block alert-info"> DSAI Notes

# %% [markdown]
# from IPython.display import Image
# from IPython.core.display import HTML
# Image(url= "https://tinyurl.com/MatplotlibSubplots ")
#
# ![Matplotlib Subplots](https://lh3.googleusercontent.com/YgqE2jH-krcr3P1gl0-z6-WcVPnArKXcGU0pNqe4oFxSn6T4TaJ6J_jbWt1YLrIVOOP93HO5FEN2gBEl11XHwFo0P1Ib1FiIoys45DYsFP-SkmwoJb6755_ftUMRIsflBoYLw_v9dRZO5aW8F_UWN1c8sGnmKexKsZJDWZsqdz3gC9rN6_nqUj-JKMb7Q3V9j4S2ceXZRmhjLXE27pEtz4r2MIsq2fsAE2qSGKyjjYR3jbSWE35XU0dj1ePl5dHCkN11UlpMZFLCFltzYDaF_M1noiAqEChUnUlATz36a4HSZk7pkEhMkMAkOssfBxK_k-xgPXBMPJfkUhtatljlJX15GZNitKtxHK2bMr1r6C9U2O3hP4geaaDizFoFPXcuz5j6ZZT7ST4M1T7NxYZbTxmUy43imfGtBzKgDDQEXF3nIrsjKOM-9dsApWoIoeXVhescDm1aHAmmPF5lB5GhIFpz7Vm9FlGMmVxfxScleOHsfFrJbMyQHAlKy-3_BWEkwIYSsvQiwh5jWI0MFBeSukFiuEtIiZOfAQztIbIopwEQt1TOOvxgkXduMA4wblh2Xvv0Hcf66EpoE5k2au0u7dcN6RxzVsaLwJMMqr1UkPUBw71en5IJyxsLhT6z3VyM0slprLmXTfsMwok8sqdcwhWlCejzkWEJ11UqIvg6iIDH8LE1a7pYBOHB8kMVUE9YEGUss9mDBMYFryiegIttYCqh7g=w1600-h1200-no)

# %% [markdown]
# ### Essential Libraries
#
# > <b> NumPy </b> : Library for Numeric Computations in Python
# > <b> Pandas  </b> : Library for Data Acquisition and Preparation
# > <b> Matplotlib  </b> : Low-level library for Data Visualization
# > <b> Seaborn  </b> : Higher-level library for Data Visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %% [markdown]
# ---
# # <div class="alert alert-block alert-success"> 1) Data Acquisition

# %% [markdown]
# 'https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table'

# %%
medal_html = pd.read_html('https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table')

# %%
print("Data type : ", type(medal_html))
print("HTML tables : ", len(medal_html))
# Out:
# Data type :  <class 'list'>
# HTML tables :  6

# %%
medal_html[0]
# Out:
#                                                    0
# 0                                Part of a series on
# 1  2016 Summer Olympics Bid process (bid details)...

# %%
medalTable = medal_html[1]
medalTable
# Out:
#                              0                    1     2       3       4  \
# 0                         Rank                  NOC  Gold  Silver  Bronze
# 1                            1  United States (USA)    46      37      38
# 2                            2  Great Britain (GBR)    27      23      17
# 3                            3          China (CHN)    26      18      26
# 4                            4         Russia (RUS)    19      17      20
# 5                            5        Germany (GER)    17      10      15
# 6                            6          Japan (JPN)    12       8      21
# 7                            7         France (FRA)    10      18      14
# 8                            8    South Korea (KOR)     9       3       9
# 9                            9          Italy (ITA)     8      12       8
# 10                          10      Australia (AUS)     8      11      10
# 11                          11    Netherlands (NED)     8       7       4
# ...

# %%
# Extract the top 21 rows of the DataFrame to capture the TOP 20 countries in the medal tally.

medalData = medalTable[:21]
medalData
# Out:
#        0                    1     2       3       4      5
# 0   Rank                  NOC  Gold  Silver  Bronze  Total
# 1      1  United States (USA)    46      37      38    121
# 2      2  Great Britain (GBR)    27      23      17     67
# 3      3          China (CHN)    26      18      26     70
# 4      4         Russia (RUS)    19      17      20     56
# 5      5        Germany (GER)    17      10      15     42
# 6      6          Japan (JPN)    12       8      21     41
# 7      7         France (FRA)    10      18      14     42
# 8      8    South Korea (KOR)     9       3       9     21
# 9      9          Italy (ITA)     8      12       8     28
# 10    10      Australia (AUS)     8      11      10     29
# 11    11    Netherlands (NED)     8       7       4     19
# 12    12        Hungary (HUN)     8       3       4     15
# 13    13        Brazil (BRA)*     7       6       6     19
# 14    14          Spain (ESP)     7       4       6     17
# ...

# %%
medalData.columns = medalData.iloc[0]  # copy 1st row to column names
medalData = medalData.drop(0)          # drop the 1st row (redundant)

# %%
medalData
# Out:
# 0  Rank                  NOC Gold Silver Bronze Total
# 1     1  United States (USA)   46     37     38   121
# 2     2  Great Britain (GBR)   27     23     17    67
# 3     3          China (CHN)   26     18     26    70
# 4     4         Russia (RUS)   19     17     20    56
# 5     5        Germany (GER)   17     10     15    42
# 6     6          Japan (JPN)   12      8     21    41
# 7     7         France (FRA)   10     18     14    42
# 8     8    South Korea (KOR)    9      3      9    21
# 9     9          Italy (ITA)    8     12      8    28
# 10   10      Australia (AUS)    8     11     10    29
# 11   11    Netherlands (NED)    8      7      4    19
# 12   12        Hungary (HUN)    8      3      4    15
# 13   13        Brazil (BRA)*    7      6      6    19
# 14   14          Spain (ESP)    7      4      6    17
# 15   15          Kenya (KEN)    6      6      1    13
# 16   16        Jamaica (JAM)    6      3      2    11
# ...

# %%
houseData = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')
houseData.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houseData.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
houseData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
houseData.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# **Observation** : Why are there less number of variables in `describe()` than in `info()`?
#
# Describe provides the basic statistics, but *only* for the Numeric Variables. You should also be careful that a variable that *looks* numeric may actually be *categorical*, as levels of categorical variables may often be encoded as numbers. However, Pandas does not know that -- it follows *duck-typing*.

# %% [markdown]
# # <div class="alert alert-block alert-danger"> END Data Acquisition
# ---
# # <div class="alert alert-block alert-success"> 2) Basic Statistics

# %%
houseDataNum = houseData.loc[:, houseData.dtypes==np.int64]
print("Data dims : ", houseDataNum.shape)
houseDataNum.info()
# Out:
# Data dims :  (1460, 35)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# LotArea          1460 non-null int64
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# BsmtFinSF1       1460 non-null int64
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# TotRmsAbvGrd     1460 non-null int64
# ...

# %%
# to include more than 2 data types
houseDataNum = houseData.select_dtypes(include = [np.int64, np.float])
houseDataNum.info()   # note that all variables are now int64 or float64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 38 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# MasVnrArea       1452 non-null float64
# BsmtFinSF1       1460 non-null int64
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# ...

# %%
# to include more than 2 data types
houseDataNum = houseData.select_dtypes(include = [np.int64], exclude = None)
print("Data dims : ", houseDataNum.shape, '\n')
houseDataNum.info()   # note that all variables are now int64
# Out:
# Data dims :  (1460, 35)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# LotArea          1460 non-null int64
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# BsmtFinSF1       1460 non-null int64
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# TotRmsAbvGrd     1460 non-null int64
# ...

# %%
droplist = ['MSSubClass','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MoSold','YrSold']

houseDataNum = houseDataNum.drop(droplist, axis=1)
houseDataNum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 28 columns):
# Id               1460 non-null int64
# LotArea          1460 non-null int64
# BsmtFinSF1       1460 non-null int64
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# TotRmsAbvGrd     1460 non-null int64
# Fireplaces       1460 non-null int64
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# ...

# %%
saleprice = pd.DataFrame(houseDataNum['SalePrice'])
print("Data type : ", type(saleprice))
print("Data dims : ", saleprice.size)
saleprice.head()
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  1460
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
saleprice.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
f, axes = plt.subplots(1,1, figsize=(24,4))
sb.boxplot(saleprice, orient="h")

# %%
f, axes = plt.subplots(1, 1, figsize=(24,12))
sb.distplot(saleprice, color="red")

# %%
f, axes = plt.subplots(1, 1, figsize=(24,12))
sb.violinplot(saleprice)

# %%
lotarea = pd.DataFrame(houseDataNum['LotArea'])
print("Data type : ", type(lotarea))
print("Data dims : ", lotarea.size)
lotarea.head()
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  1460
#    LotArea
# 0     8450
# 1     9600
# 2    11250
# 3     9550
# 4    14260

# %%
lotarea.describe()
# Out:
#              LotArea
# count    1460.000000
# mean    10516.828082
# std      9981.264932
# min      1300.000000
# 25%      7553.500000
# 50%      9478.500000
# 75%     11601.500000
# max    215245.000000

# %%
f, axes = plt.subplots(1, 1, figsize=(12, 2))
sb.boxplot(lotarea)

# %%
f, axes = plt.subplots(1, 1, figsize=(12,8))
sb.distplot(lotarea, color="red", kde=True)

# %%
f, axes = plt.subplots(1, 1, figsize=(24,12))
sb.violinplot(lotarea, color="b")

# %%
saleprice = pd.DataFrame(houseDataNum['SalePrice'])
lotarea = pd.DataFrame(houseDataNum['LotArea'])

# %%
# Setup matplotlib figure with 3 subplots
f, axes = plt.subplots(2,3, figsize=(24,12))

# Plot basic uni-variate figures for SalePrice
sb.boxplot(saleprice, orient="h", ax=axes[0,0])
sb.distplot(saleprice, kde=False, ax=axes[0,1])
sb.violinplot(saleprice, ax=axes[0,2])

# Plot basic uni-variate figures for LotArea
sb.boxplot(lotarea, orient="h", ax=axes[1,0], color='green')
sb.distplot(lotarea, hist=False, ax=axes[1,1], color='green')
sb.violinplot(lotarea, ax=axes[1,2], color='green')

# %%
sb.jointplot(x=lotarea, y=saleprice, height=20, kind='scatter', color='blue', edgecolor="w").plot_joint(sb.kdeplot, zorder=0, n_levels=6)

# %%
# Create a joint dataframe by concatenating the 2 variables
jointDF = pd.concat([lotarea, saleprice], axis=1, join_axes=[lotarea.index])

# Calculate the correlation btw the 2 columns/variables
jointDF.corr()
# Out:
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000

# %%
jointDF = pd.concat([lotarea, saleprice], axis=1, join_axes=[lotarea.index])
jointDF['LotArea'][1179] # To look at a specific index
# Out:
# 8335

# %%
sb.heatmap(jointDF.corr(), vmin=-1, vmax=1, annot=True, fmt=".2f")

# %% [markdown]
# # <div class="alert alert-block alert-danger"> END Basic Statistics
# ---
# # <div class="alert alert-block alert-success"> 3) Exploratory Analysis

# %%
houseData3 = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')
houseData3.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houseNumData3 = pd.DataFrame(houseData3[['LotArea', 'GrLivArea', 'TotalBsmtSF', 'GarageArea', 'SalePrice']])
houseNumData3.head()
# Out:
#    LotArea  GrLivArea  TotalBsmtSF  GarageArea  SalePrice
# 0     8450       1710          856         548     208500
# 1     9600       1262         1262         460     181500
# 2    11250       1786          920         608     223500
# 3     9550       1717          756         642     140000
# 4    14260       2198         1145         836     250000

# %%
houseNumData3.describe()
# Out:
#              LotArea    GrLivArea  TotalBsmtSF   GarageArea      SalePrice
# count    1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    10516.828082  1515.463699  1057.429452   472.980137  180921.195890
# std      9981.264932   525.480383   438.705324   213.804841   79442.502883
# min      1300.000000   334.000000     0.000000     0.000000   34900.000000
# 25%      7553.500000  1129.500000   795.750000   334.500000  129975.000000
# 50%      9478.500000  1464.000000   991.500000   480.000000  163000.000000
# 75%     11601.500000  1776.750000  1298.250000   576.000000  214000.000000
# max    215245.000000  5642.000000  6110.000000  1418.000000  755000.000000

# %%
# Draw distribution of all variables 
f, axes = plt.subplots(5, 3, figsize=(18,20))
colors = ["red", "green", "blue", "magenta", "cyan"]

count = 0
for var in houseNumData3:
    sb.boxplot(houseNumData3[var], orient="h", color=colors[count], ax=axes[count,0])
    sb.distplot(houseData3[var], color=colors[count], ax=axes[count,1])
    sb.violinplot(houseNumData3[var], color=colors[count], ax=axes[count,2])
    count += 1

# %%
# Correlation Matrix
print(houseNumData3.corr())

# Heatmap of the Correlation Matrix
f, axes = plt.subplots(1,1,figsize=(20,20))
sb.heatmap(houseNumData3.corr(), vmin=-1, vmax=1, linewidths=2,
          annot=True, fmt=".2f", annot_kws={"size":18}, cmap="RdBu")
# Out:
#               LotArea  GrLivArea  TotalBsmtSF  GarageArea  SalePrice
# LotArea      1.000000   0.263116     0.260833    0.180403   0.263843
# GrLivArea    0.263116   1.000000     0.454868    0.468997   0.708624
# TotalBsmtSF  0.260833   0.454868     1.000000    0.486665   0.613581
# GarageArea   0.180403   0.468997     0.486665    1.000000   0.623431
# SalePrice    0.263843   0.708624     0.613581    0.623431   1.000000

# %%
# Draw pairs of variables against one another 
sb.pairplot(data=houseNumData3)

# %% [markdown]
# **Which variables do you think will help us predict `SalePrice` in this dataset?**
#
# > `GrLivArea` : Possibly the most important variable :
# Highest Correlation, Strong Linearity
# > `GarageArea` and `TotalBsmtSF` : Important variables :
# High Correlation, Strong Linearity
# > `LotArea` : Doesn't seem so important as a variable :
# Low Correlation, Weak Linear Relation

# %%
houseCatData = pd.DataFrame(houseData[['MSSubClass', 'Neighborhood', 'BldgType', 'OverallQual']])
houseCatData.head()
# Out:
#    MSSubClass Neighborhood BldgType  OverallQual
# 0          60      CollgCr     1Fam            7
# 1          20      Veenker     1Fam            6
# 2          60      CollgCr     1Fam            7
# 3          70      Crawfor     1Fam            7
# 4          60      NoRidge     1Fam            8

# %%
# Change Datatype to Category
for var in houseCatData:
    houseCatData[var] = houseCatData[var].astype('category')

# %%
houseCatData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 4 columns):
# MSSubClass      1460 non-null category
# Neighborhood    1460 non-null category
# BldgType        1460 non-null category
# OverallQual     1460 non-null category
# dtypes: category(4)
# memory usage: 7.9 KB

# %%
houseCatData.describe()
# no of data points
# number of unique categories
# most freq category 
# freq of most freq category
# Out:
#         MSSubClass Neighborhood BldgType  OverallQual
# count         1460         1460     1460         1460
# unique          15           25        5           10
# top             20        NAmes     1Fam            5
# freq           536          225     1220          397

# %%
# figure-level-and-axes-level-functions
# http://seaborn.pydata.org/introduction.html
    
count=0
for var in houseCatData:
    sb.catplot(y=var, data=houseCatData, kind="count", height=8)

# %%
# Distribution of BldgType across MSSubClass
f, axes = plt.subplots(1, 1, figsize=(20,8))
sb.heatmap(houseCatData.groupby(['BldgType', 'MSSubClass']).size().unstack(),
           linewidths=1, annot=True, fmt='g', annot_kws={'size':18}, cmap="BuGn")

# %%
# Distribution of OverallQual across other columns
f, axes = plt.subplots(3,1,figsize=(20,24))

count=0
for var in houseCatData:
    if var != 'OverallQual':
        sb.heatmap(houseCatData.groupby(['OverallQual', var]).size().unstack(),
                  linewidths=1, annot=True, fmt='g', annot_kws={'size':18}, cmap="BuGn", ax=axes[count])
    count += 1

# %%
# Create joint DataFrame by concatenating SalePrice to houseCatData
saleprice = pd.DataFrame(houseData['SalePrice'])
houseCatSale = pd.concat([houseCatData, saleprice], axis=1, join_axes=[houseCatData.index])
houseCatSale.head()
# Out:
#   MSSubClass Neighborhood BldgType OverallQual  SalePrice
# 0         60      CollgCr     1Fam           7     208500
# 1         20      Veenker     1Fam           6     181500
# 2         60      CollgCr     1Fam           7     223500
# 3         70      Crawfor     1Fam           7     140000
# 4         60      NoRidge     1Fam           8     250000

# %%
# Effect of Variables on SalePrice using boxplot
f, axes = plt.subplots(4,1,figsize=(12,16))

count=0
for var in houseCatData:
    sb.boxplot(x=var, y='SalePrice', data=houseCatSale, ax=axes[count])
    count += 1

# Rotate ticklabels for 'Neighborhood'
tl = axes[1].get_xticklabels()
axes[1].set_xticklabels(tl, rotation=45);


### Rotate ticklabels for all variables ###
# for ax in axes:
#     tl = ax.get_xticklabels()
#     ax.set_xticklabels(tl, rotation=45)
#     tly = ax.get_yticklabels()
#     ax.set_yticklabels(tly, rotation=0)

# %%
f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.boxplot(x = 'Neighborhood', y = 'SalePrice', data = houseCatSale)
plt.xticks(rotation=90);

# %% [markdown]
# **Which variables do you think will help us predict `SalePrice` in this dataset?**
#
# > `OverallQual` : Definitely the most important variable : Highest variation in `SalePrice` across the levels
# > `Neighborhood` and `MSSubClass` : Moderately important variables : Medium variation in `SalePrice` across levels
# > `BldgType` : Not clear if important as a variable at all : Not much variation in `SalePrice` across the levels

# %% [markdown]
# # <div class="alert alert-block alert-danger"> END Exploratory Analysis
# ---
# # <div class="alert alert-block alert-success"> 4) Linear Regression
#     from sklearn.linear_model import LinearRegression
#     from sklearn.model_selection import train_test_split
#     from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### You should also try the following
#
# * Convert `SalePrice` to `log(SalePrice)` in the beginning and then use it for Regression
#   > <b>Code :</b>
#          houseSalePrice = pd.DataFrame(np.log(houseData['SalePrice']))
#
# * Perform a `Random Train-Test Split` on the dataset before you start with the Regression
#   From *M3 LinearRegression.ipynb*:
#   > <b>Code :</b>
#          X_train, X_test, y_train, y_test = train_test_split(hp, total, test_size = 0.25)

# %%
houseData4 = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')
houseData4.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houseGrLivArea = pd.DataFrame(houseData4['GrLivArea'])
houseSalePrice = pd.DataFrame(houseData4['SalePrice'])

# Against Log Sale Price
houseLOGSalePrice = pd.DataFrame(np.log(houseData4['SalePrice']))

# %%
sb.jointplot(x=houseGrLivArea, y=houseSalePrice, height=12, edgecolor='w').set_axis_labels("houseGrLivArea", "houseSalePrice")
sb.jointplot(x=houseGrLivArea, y=houseLOGSalePrice, height=12, edgecolor='w').set_axis_labels("houseGrLivArea", "houseLOG(SalePrice)");

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Lienar Regression object
linreg = LinearRegression()
linreg_RTTS = LinearRegression()

# %%
houseGrLivArea.shape, houseSalePrice.shape
# Out:
# ((1460, 1), (1460, 1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Split dataset into Train & Test
houseGrLivArea_train = pd.DataFrame(houseGrLivArea[:1100])
houseGrLivArea_test = pd.DataFrame(houseGrLivArea[-360:]) # [(1100-1460):] || [1100:]
houseSalePrice_train = pd.DataFrame(houseSalePrice[:1100])
houseSalePrice_test = pd.DataFrame(houseSalePrice[-360:])

# Random Train-Test Split using "houseLOGSalePrice" # Either int(number)/float(%tage)
x_train, x_test, y_train, y_test = train_test_split(houseGrLivArea, houseLOGSalePrice, test_size = 360) 


# Check sample sizes
print("Train Set :", houseGrLivArea_train.shape, houseSalePrice_train.shape)
print("Test Set :", houseGrLivArea_test.shape, houseSalePrice_test.shape, "\n")

print("('RTTS') LOG Train Set :", x_train.shape, y_train.shape)
print("('RTTS') LOG Test Set :", y_test.shape, y_test.shape)
# Out:
# Train Set : (1100, 1) (1100, 1)
# Test Set : (360, 1) (360, 1)
#
# ('RTTS') LOG Train Set : (1100, 1) (1100, 1)
# ('RTTS') LOG Test Set : (360, 1) (360, 1)

# %%
# Fit LinReg model on houseGrLivArea_train & houseSalePrice_train
linreg.fit(houseGrLivArea_train, houseSalePrice_train)

# Fit LinReg model on RTTS houseGrLivArea_train & RTTS houseLOGSalePrice_train
linreg_RTTS.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Coeffs of LinReg model 
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_, "\n") # or linreg.coef_[0]

# Coeffs of RTTS LOG LinReg model 
print('Intercept \t: b = ', linreg_RTTS.intercept_)
print('Coefficients \t: a = ', linreg_RTTS.coef_) # or linreg.coef_[0]
# Out:
# Intercept 	: b =  [9498.33463562]
# Coefficients 	: a =  [[113.88950443]]
#
# Intercept 	: b =  [11.24608921]
# Coefficients 	: a =  [[0.00051827]]

# %%
# Formula for LinReg line
regline_x = houseGrLivArea_train
regline_y = linreg.intercept_ + linreg.coef_ * houseGrLivArea_train

regline_RTTS_x = x_train
regline_RTTS_y = linreg_RTTS.intercept_ + linreg_RTTS.coef_ * x_train

# Plot LinReg line
f, axes = plt.subplots(1,2,figsize=(16,8))
axes[0].scatter(houseGrLivArea_train, houseSalePrice_train, edgecolors='white')
axes[0].plot(regline_x, regline_y, 'r:', linewidth=3)
axes[0].set_xlabel("SalePrice_train (0-1100)")
axes[0].set_ylabel("HouseGrLivArea_train (0-1100)")

axes[1].scatter(x_train, y_train, edgecolors='white')
axes[1].plot(regline_RTTS_x, regline_RTTS_y, 'r:', linewidth=3)
axes[1].set_xlabel("houseLOGSalePrice (RTTS)")
axes[1].set_ylabel("HouseGrLivArea_train (RTTS)")
plt.show()

# %%
# Predict Response based on Predictor
# Predict 'SalePrice' values corresponding to 'GrLivArea' in the test dataset
houseSalePrice_test_pred = linreg.predict(houseGrLivArea_test)
houseLOGSalePrice_test_pred = linreg_RTTS.predict(x_test)

# Plot the Predictions 
f, axes = plt.subplots(1,2,figsize=(16,8))
axes[0].scatter(houseGrLivArea_test, houseSalePrice_test, color="g", edgecolors='w')
axes[0].scatter(houseGrLivArea_test, houseSalePrice_test_pred, color="red", s=10)
axes[0].set_xlabel("houseGrLivArea_test")
axes[0].set_ylabel("houseSalePrice_test_pred")

axes[1].scatter(x_test, y_test, color='g', edgecolors='w')
axes[1].scatter(x_test, houseLOGSalePrice_test_pred, color='red', s=10)
axes[1].set_xlabel("x_test")
axes[1].set_ylabel("houseLOGSalePrice_test_pred")
plt.show()

# %%
# Goodness of Fit of the LinReg model => Check how good predictions are on "TRAIN SET"/"TEST SET"

# Metric: Explained Variance (R^2) on "TRAIN SET"
print("Exlained Variance (R^2) on 'TRAIN SET' \t:", 
      linreg.score(houseGrLivArea_train, houseSalePrice_train))
print("Exlained Variance (R^2) on 'RTTS_TRAIN SET' with log(SalePrice) \t:", 
      linreg_RTTS.score(x_train, y_train), "\n")

# Metric: Explained Variance (R^2) on "TEST SET"
print("Explained Variance (R^2) on 'TEST SET' \t:",
      linreg.score(houseGrLivArea_test, houseSalePrice_test))
print("Explained Variance (R^2) on 'RTTS_TEST SET' with log(SalePrice) \t:",
      linreg_RTTS.score(x_test, y_test))
# Out:
# Exlained Variance (R^2) on 'TRAIN SET' 	: 0.5317704755454566
# Exlained Variance (R^2) on 'RTTS_TRAIN SET' with log(SalePrice) 	: 0.48720441665715924
#
# Explained Variance (R^2) on 'TEST SET' 	: 0.40117720006925806
# Explained Variance (R^2) on 'RTTS_TEST SET' with log(SalePrice) 	: 0.4911910152970086

# %% [markdown]
# ---

# %% [markdown]
# ### For 'LotArea',
# ##### Use higher power is better to increase distance btw data points:
# houseSalePrice = pd.DataFrame(`np.power`(houseData4['SalePrice], 3.5)`)
#
# #### More Accurate:
#     Explained Variance (R^2) on 'TRAIN SET': 0.026910225700620516
#     Explained Variance (R^2) on 'TEST SET' : 0.02100473067907216

# %%
# Predicting SalePrice using LotArea 
housePredictor = pd.DataFrame(houseData4['LotArea'])
houseSalePrice = pd.DataFrame(houseData4['SalePrice'])
sb.jointplot(housePredictor, houseSalePrice, height=12, edgecolor='w')

# %%
# LinReg on SalePrice vs Predictor ('LotArea')

# Import LinReg model from SciKit-Learn
from sklearn.linear_model import LinearRegression

# Split dataset into train/test
housePredictor_train = pd.DataFrame(housePredictor[:1100])
housePredictor_test = pd.DataFrame(housePredictor[-360:])
houseSalePrice_train = pd.DataFrame(houseSalePrice[:1100])
houseSalePrice_test = pd.DataFrame(houseSalePrice[-360:])

# Create LinReg obj
linreg2 = LinearRegression()

# Train LinReg model 
linreg2.fit(housePredictor_train, houseSalePrice_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Visual representation of LinReg model
print("Intercept \t: b = ", linreg2.intercept_)
print("Coefficients \t: a = ", linreg2.coef_)

# Formula for LinReg line
regline2_x = housePredictor_train
regline2_y = linreg2.intercept_ + linreg2.coef_ * housePredictor_train

# Plot the LinReg line 
f, axes = plt.subplots(1,1,figsize=(16,8))
plt.scatter(housePredictor_train, houseSalePrice_train, edgecolors='w')
plt.plot(regline2_x, regline2_y, 'r-', linewidth=3)
plt.show()
# Out:
# Intercept 	: b =  [160963.95370929]
# Coefficients 	: a =  [[1.91881242]]

# %%
# Prediction of Response (SalePrice) based on the Predictor ('LotArea')

# Predict SalePrice values corresponding to LotArea
houseSalePrice_test_pred2 = linreg2.predict(housePredictor_test)

# Plot Predictions
f, axes = plt.subplots(1,1,figsize=(16,8))
plt.scatter(housePredictor_test, houseSalePrice_test, color="green", edgecolors='w')
plt.scatter(housePredictor_test, houseSalePrice_test_pred2, color="red", s=10);

# %%
# Goodness of fit of LinReg model 
print("Explained Variance (R^2) on 'TRAIN SET'\t: ",
     linreg2.score(housePredictor_train, houseSalePrice_train))
print("Explained Variance (R^2) on 'TEST SET'\t: ",
     linreg2.score(housePredictor_test, houseSalePrice_test))
# Out:
# Explained Variance (R^2) on 'TRAIN SET'	:  0.06996047063721678
# Explained Variance (R^2) on 'TEST SET'	:  0.0661786844889618

# %% [markdown]
# ---

# %%
housePredictor2 = pd.DataFrame(houseData['TotalBsmtSF'])
houseSalePrice = pd.DataFrame(houseData['SalePrice'])
sb.jointplot(housePredictor2, houseSalePrice, height = 12)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Split the dataset into Train and Test       
housePredictor2_train = pd.DataFrame(housePredictor2[:1100])
housePredictor2_test = pd.DataFrame(housePredictor2[-360:])
houseSalePrice_train;
houseSalePrice_test;

# Create a Linear Regression object
linreg3 = LinearRegression()

# Train the Linear Regression model
linreg3.fit(housePredictor2_train, houseSalePrice_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Visual Representation of the Linear Regression Model
print('Intercept \t: b = ', linreg3.intercept_)
print('Coefficients \t: a = ', linreg3.coef_)

# Formula for the Regression line
regline3_x = housePredictor2_train
regline3_y = linreg3.intercept_ + linreg3.coef_ * housePredictor2_train

# Plot the Linear Regression line
f, axes = plt.subplots(1,1,figsize=(16,8))
plt.scatter(housePredictor2_train, houseSalePrice_train, edgecolors='w')
plt.plot(regline3_x, regline3_y, 'r-', linewidth=3);
# Out:
# Intercept 	: b =  [54361.70161283]
# Coefficients 	: a =  [[120.19979559]]

# %%
# Prediction of Response based on the Predictor¶
houseSalePrice_test_pred3 = linreg3.predict(housePredictor2_test)

# Plot the Predictions
f, axes = plt.subplots(1,1,figsize=(16,8))
plt.scatter(housePredictor2_test, houseSalePrice_test, color='green', edgecolors='w')
plt.scatter(housePredictor2_test, houseSalePrice_test_pred3, color='red');

# %%
print("Explained Variance (R^2) on 'TRAIN SET'\t:", 
      linreg3.score(housePredictor2_train, houseSalePrice_train))
print("Explained Variance (R^2) on 'TEST SET'\t:", 
      linreg3.score(housePredictor2_test, houseSalePrice_test))
# Out:
# Explained Variance (R^2) on 'TRAIN SET'	: 0.40965154133422405
# Explained Variance (R^2) on 'TEST SET'	: 0.26305378699344206

# %% [markdown]
# ---

# %%
# Predicting SalePrice using GarageArea
housePredictor3 = pd.DataFrame(houseData4['GarageArea'])
houseSalePrice = pd.DataFrame(houseData4['SalePrice'])
sb.jointplot(housePredictor3, houseSalePrice, height=12)

# %%
from sklearn.linear_model import LinearRegression

# Split the dataset into Train and Test       
housePredictor3_train = pd.DataFrame(housePredictor3[:1100])
housePredictor3_test  = pd.DataFrame(housePredictor3[-360:])
houseSalePrice_train;
houseSalePrice_test;

# Create a Linear Regression object
linreg4 = LinearRegression()

# Train the Linear Regression model
linreg4.fit(housePredictor3_train, houseSalePrice_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Visual Representation of the Linear Regression Model
print('Intercept \t: b = ', linreg4.intercept_)
print('Coefficients \t: a = ', linreg4.coef_)

# Formula for the Regression line
regline4_x = housePredictor3_train
regline4_y = linreg4.intercept_ + linreg4.coef_ * housePredictor3_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(housePredictor3_train, houseSalePrice_train)
plt.plot(regline4_x, regline4_y, 'r-', linewidth = 3)
plt.show()
# Out:
# Intercept 	: b =  [67131.98072434]
# Coefficients 	: a =  [[241.42776434]]

# %%
# Predict SalePrice values corresponding to GrLivArea
houseSalePrice_test_pred3 = linreg4.predict(housePredictor3_test)

# Plot the Predictions
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(housePredictor3_test, houseSalePrice_test, color = "green")
plt.scatter(housePredictor3_test, houseSalePrice_test_pred3, color = "red")
plt.show()

# %%
print("Explained Variance (R^2) on Train Set \t:", 
      linreg4.score(housePredictor3_train, houseSalePrice_train))
print("Explained Variance (R^2) on Test Set \t:", 
      linreg4.score(housePredictor3_test, houseSalePrice_test))
# Out:
# Explained Variance (R^2) on Train Set 	: 0.40526589947579356
# Explained Variance (R^2) on Test Set 	: 0.33415894889143827

# %% [markdown]
# ---
# ### Extra : Predicting SalePrice using Multiple Variables

# %%
housePredictorAll = pd.DataFrame(houseData4[['GrLivArea', 'LotArea', 'TotalBsmtSF', 'GarageArea']])
houseSalePrice = pd.DataFrame(houseData4['SalePrice'])

# %%
# Linear Regression on SalePrice vs Predictor
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Split the dataset into Train and Test       
housePredictorAll_train = pd.DataFrame(housePredictorAll[:1100])
housePredictorAll_test  = pd.DataFrame(housePredictorAll[-360:])
houseSalePrice_train;
houseSalePrice_test;

# Create a Linear Regression object
linregAll = LinearRegression()

# Train the Linear Regression model
linregAll.fit(housePredictorAll_train, houseSalePrice_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# #### <b>Coefficients of the Linear Regression Model</b>
#
# Note that you CANNOT visualize the model as a line on a 2D plot, as it is a multi-dimensional surface.

# %%
print('Intercept\t: b =', linregAll.intercept_)
print('Coefficients\t: a =', linregAll.coef_)
# Out:
# Intercept	: b = [-39905.07765158]
# Coefficients	: a = [[ 72.39802739   0.32388634  57.56031344 101.09427406]]

# %%
# Prediction of Response based on the Predictor
# Predict SalePrice values corresponding to 
houseSalePrice_train_predAll = linregAll.predict(housePredictorAll_train)
houseSalePrice_test_predAll = linregAll.predict(housePredictorAll_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(houseSalePrice_train, houseSalePrice_train_predAll, color = "blue")
axes[0].plot(houseSalePrice_train, houseSalePrice_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")

axes[1].scatter(houseSalePrice_test, houseSalePrice_test_predAll, color = "green")
axes[1].plot(houseSalePrice_test, houseSalePrice_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
print("Explained Variance (R^2) on Train Set \t:", 
      linregAll.score(housePredictorAll_train, houseSalePrice_train))
print("Explained Variance (R^2) on Test Set \t:", 
      linregAll.score(housePredictorAll_test, houseSalePrice_test))
# Out:
# Explained Variance (R^2) on Train Set 	: 0.7157180280767486
# Explained Variance (R^2) on Test Set 	: 0.47669782999775623

# %% [markdown]
# ---
#
# ## Interpretation and Discussion
#
# After performing Linear Regression of `SalePrice` against the four variables `GrLivArea`, `LotArea`, `TotalBsmtSF`, `GarageArea`, compare-and-contrast the Exaplained Variance (R^2) to determine which model is the best in order to predict `SalePrice`. What do you think?

# %% [markdown]
# #### GrLivArea
# >Explained Variance (R^2) on Train Set : 0.5317704755454566
# >Explained Variance (R^2) on Test Set  : 0.40117720006925806
#
# #### LotArea
# >Explained Variance (R^2) on Train Set : 0.06996047063721678
# >Explained Variance (R^2) on Test Set   : 0.0661786844889618
#
# #### TotalBsmtSF
# >Explained Variance (R^2) on Train Set : 0.40965154133422405
# >Explained Variance (R^2) on Test Set   : 0.26305378699344206
#
# #### GarageArea
# >Explained Variance (R^2) on Train Set : 0.40526589947579356
# >Explained Variance (R^2) on Test Set   : 0.33415894889143827

# %% [markdown]
# ### Strongest to weakest correlation
# > LotArea, TotalBsmtSF/GarageArea, GrLivArea

# %% [markdown]
# # <div class="alert alert-block alert-danger"> END Linear Regression
# ---
#
# # <div class="alert alert-block alert-success"> 5) Classification Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
import graphviz

# %% [markdown]
# ---

# %%
# Predicting CentralAir using SalePrice
houseData['CentralAir'].describe()
# Out:
# count     1460
# unique       2
# top          Y
# freq      1365
# Name: CentralAir, dtype: object

# %%
sb.catplot(y='CentralAir', data=houseData, kind="count")

# %% [markdown]
# The 2 levels of `CentralAir`, `Y` and `N`, are drastically imbalanced. This is not a very good situation for a classification problem. It is desirable to have *balanced* classes for classification, and there are several methods to make imbalanced classes balanced, or to get desired classification results even from imbalanced classes. If you are interested, check out the following article.
# https://machinelearningmastery.com/tactics-to-combat-imbalanced-classes-in-your-machine-learning-dataset/

# %%
# `CentralAir` against `SalePrice` visualization
f, axes = plt.subplots(1,1,figsize=(16,8))
sb.boxplot('SalePrice', 'CentralAir', data=houseData)

# %% [markdown]
# Note that the 2 boxplots for `SalePrice`,`CentralAir = Y`/`CentralAir = N`, are very different from one another in terms of their <b>median & spread</b>. This means that `CentralAir` has an effect on `SalePrice`, and hence, `SalePrice` will probably be an important variable in predicting `CentralAir`. Boxplots do not tell us where to make the cuts though -- it will be easier to visualize in the following `swarmplot`.

# %%
f, axes = plt.subplots(2,1,figsize=(16,16))
sb.swarmplot('SalePrice', 'CentralAir', data=houseData, hue='OverallQual', dodge=True, ax=axes[0])
sb.swarmplot('SalePrice', 'CentralAir', data=houseData, s=4, ax=axes[1])
axes[1] = sb.boxplot('SalePrice', 'CentralAir', data=houseData)

# %% [markdown]
# Build the Decision Tree classifier. Import `DecisionTreeClassifier` model from `sklearn.tree`.

# %%
# Import Decision Tree Classififier model from Scikit-Learn
from sklearn.tree import DecisionTreeClassifier

# Create a Decision Tree Classifier obj
dectree = DecisionTreeClassifier(max_depth=2)

# %%
# Split the dataset into Train and Test       
houseData_train = pd.DataFrame(houseData[:1100])
houseData_test  = pd.DataFrame(houseData[-360:])

# Check the sample sizes
print("Train Set :", houseData_train.shape)
print("Test Set  :", houseData_test.shape)
# Out:
# Train Set : (1100, 81)
# Test Set  : (360, 81)

# %% [markdown]
# Train the Decision Tree Classifier model `dectree` using the Train Set.

# %%
# Extract the 2 variables X_train and y_train
x_trainn = pd.DataFrame(houseData_train['SalePrice'])
y_trainn = pd.DataFrame(houseData_train['CentralAir'])

# Train the Decision Tree Classifier model
dectree.fit(x_trainn, y_trainn)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# #### Visual Representation of the Decision Tree Model
#
# Export the Decision Tree as a `dot` file using `export_graphviz`, and visualize.

# %%
# Visual Representtion of the Decision Tree Model
from sklearn.tree import export_graphviz

# Export the Decision Tree as a dot obj
treedot = export_graphviz(dectree, 
                         feature_names = x_trainn.columns,
                         out_file=None,
                         filled=True,
                         rounded=True,
                         special_characters=True)

# Render using graphviz
import graphviz
graphviz.Source(treedot)

# %% [markdown]
# #### Goodness of Fit of the Model -> Relate to Train Set
#
# Check how good predictions are on Train Set.
# <b>Metrics :</b> `Classification Accuracy` & `Confusion Matrix`.
#
# >`Accuracy:` Overall, how often is the classifier correct?
# <img src="https://classeval.files.wordpress.com/2015/06/accuracy.png?w=880&h=310">
#
# >`Precision:` When a positive value is predicted, how often is the prediction correct?
# <img src="https://classeval.files.wordpress.com/2015/06/precision.png?w=880&h=310">
#
# >`Sensitivity:` When the actual value is positive, how often is the prediction correct?
# <img src="https://classeval.files.wordpress.com/2015/06/sensitivity.png?w=880&h=310">
#
# >`Specificity:` When the actual value is negative, how often is the prediction correct?
# <img src="https://classeval.files.wordpress.com/2015/06/specificity.png?w=880&h=310">
#
# <img src="https://3.bp.blogspot.com/--jLXutUe5Ss/VvPIO6ZH2tI/AAAAAAAACkU/pvVL4L-a70gnFEURcfBbL_R-GnhBR6f1Q/s1600/ConfusionMatrix.png">

# %%
# Predict the Response corresponding to Predictors
y_train_pred = dectree.predict(x_trainn)

# Print Classification Accuracy 
print("Classification Accuracy \t:", dectree.score(x_trainn, y_trainn))

# Plot the 2-way Confusion Matirx
from sklearn.metrics import confusion_matrix
sb.heatmap(confusion_matrix(y_trainn, y_train_pred),
          annot=True, fmt=".0f", annot_kws={"size":18});
# Out:
# Classification Accuracy 	: 0.94

# %%
from sklearn.metrics import confusion_matrix
train_confusion = confusion_matrix(y_trainn, y_train_pred)
# print(train_confusion)
TP, TN, FP, FN = train_confusion[1, 1], train_confusion[0, 0], train_confusion[0, 1], train_confusion[1, 0]

from sklearn import metrics
# Overall, how often is the classifier correct?
accuracy = (TP + TN) / float(TP + TN + FP + FN)
print("Classification Accuracy \t:", dectree.score(x_trainn, y_trainn)) # metrics.accuracy_score(y_trainn, y_train_pred)

# When a positive value is predicted, how often is the prediction correct?
precision = TP / float(TP + FP)
print("Classification Precision\t:", precision)

# When the actual value is positive, how often is the prediction correct?
sensitivity = TP / float(FN + TP)
print("Classification Sensitivity\t:", sensitivity)

# When the actual value is negative, how often is the prediction correct?
specificity = TN / (TN + FP)
print("Classification Specificity\t:", specificity)
# Out:
# Classification Accuracy 	: 0.94
# Classification Precision	: 0.9460966542750929
# Classification Sensitivity	: 0.9922027290448343
# Classification Specificity	: 0.21621621621621623

# %% [markdown]
# #### Prediction of Response based on the Predictor -> Relate to Test Set
#
# Check how good the predictions are on the Test Set.
# <b>Metrics :</b> `Classification Accuracy` & `Confusion Matrix`.

# %%
# Extract the two variables X_test and y_test
x_testt = pd.DataFrame(houseData_test['SalePrice'])
y_testt = pd.DataFrame(houseData_test['CentralAir'])

# Predict the Response corresponding to Predictors
y_test_pred = dectree.predict(x_testt)

# Print Classification Accuracy
print("Classification Accuracy \t:", dectree.score(x_testt, y_testt))

# Plot the 2-way Confusion Matrix 
from sklearn.metrics import confusion_matrix
sb.heatmap(confusion_matrix(y_testt, y_test_pred),
          annot=True, fmt=".0f", annot_kws={"size":18});
# Out:
# Classification Accuracy 	: 0.9472222222222222

# %%
from sklearn.metrics import confusion_matrix
test_confusion = confusion_matrix(y_testt, y_test_pred)
# print(test_confusion)
TP2, TN2, FP2, FN2 = test_confusion[1, 1], test_confusion[0, 0], test_confusion[0, 1], test_confusion[1, 0]

from sklearn import metrics
# Overall, how often is the classifier correct?
accuracy = (TP2 + TN2) / float(TP2 + TN2 + FP2 + FN2)
print("Classification Accuracy \t:", dectree.score(x_testt, y_testt)) # metrics.accuracy_score(y_trainn, y_train_pred)

# When a positive value is predicted, how often is the prediction correct?
precision = TP2 / float(TP2 + FP2)
print("Classification Precision\t:", precision)

# When the actual value is positive, how often is the prediction correct?
sensitivity = TP2 / float(FN2 + TP2)
print("Classification Sensitivity\t:", sensitivity)

# When the actual value is negative, how often is the prediction correct?
specificity = TN2 / (TN2 + FP2)
print("Classification Specificity\t:", specificity)
# Out:
# Classification Accuracy 	: 0.9472222222222222
# Classification Precision	: 0.9545454545454546
# Classification Sensitivity	: 0.9911504424778761
# Classification Specificity	: 0.23809523809523808

# %% [markdown]
# **Important** : Note the huge imbalance in the *False Positives* and *False Negatives* in the confusion matrix.
#
# >For Training Data, `False Positives=58` whereas `False Negatives=8`.
#
# >For Test Data, `False Positives=16` whereas `False Negatives=3`.
#
# This should not be surprising, this is a direct effect of the huge `Y` vs `N` imbalance in the `CentralAir` variable.
# > As `CentralAir = Y` was more likely in the data, *False Positives* are more likely too.

# %% [markdown]
# ---

# %% [markdown]
# ### Predicting CentralAir using 'GrLivArea'

# %%
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
import graphviz

# Extract Response and Predictors
y = pd.DataFrame(houseData['CentralAir'])
x = pd.DataFrame(houseData['GrLivArea'])

# Split the Dataset into Train and Test
x_trainnn, x_testtt, y_trainnn, y_testtt = train_test_split(x, y, test_size = 360)

# Decision Tree using Train Data
dectree5 = DecisionTreeClassifier(max_depth = 2)  # create the decision tree object
dectree5.fit(x_trainnn, y_trainnn)                # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred5 = dectree5.predict(x_trainnn)
y_test_pred5 = dectree5.predict(x_testtt)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree5.score(x_trainnn, y_trainnn), "\n")

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree5.score(x_testtt, y_testtt), "\n")

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_trainnn, y_train_pred5),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_testtt, y_test_pred5), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Plot the Decision Tree
treedot5 = export_graphviz(dectree5,                            # the model
                          feature_names =x_trainnn.columns,     # the features 
                          out_file = None,                      # output file
                          filled = True,                        # node colors
                          rounded = True,                       # make pretty
                          special_characters = True)            # postscript

graphviz.Source(treedot5)
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9381818181818182
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9361111111111111

# %% [markdown]
# ### Predicting CentralAir using 'LotArea'

# %%
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
import graphviz

# Extract Response and Predictors
y = pd.DataFrame(houseData['CentralAir'])
x = pd.DataFrame(houseData['LotArea'])

# Split the Dataset into Train and Test
x_trainnn, x_testtt, y_trainnn, y_testtt = train_test_split(x, y, test_size = 360)

# Decision Tree using Train Data
dectree5 = DecisionTreeClassifier(max_depth = 2)  # create the decision tree object
dectree5.fit(x_trainnn, y_trainnn)                # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred5 = dectree5.predict(x_trainnn)
y_test_pred5 = dectree5.predict(x_testtt)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree5.score(x_trainnn, y_trainnn), "\n")

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree5.score(x_testtt, y_testtt), "\n")

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_trainnn, y_train_pred5),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_testtt, y_test_pred5), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Plot the Decision Tree
treedot5 = export_graphviz(dectree5,                            # the model
                          feature_names =x_trainnn.columns,     # the features 
                          out_file = None,                      # output file
                          filled = True,                        # node colors
                          rounded = True,                       # make pretty
                          special_characters = True)            # postscript

graphviz.Source(treedot5)
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9381818181818182
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.925

# %% [markdown]
# ### Predicting CentralAir using 'TotalBsmtSF'

# %%
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
import graphviz

# Extract Response and Predictors
y = pd.DataFrame(houseData['CentralAir'])
x = pd.DataFrame(houseData['TotalBsmtSF'])

# Split the Dataset into Train and Test
x_trainnn, x_testtt, y_trainnn, y_testtt = train_test_split(x, y, test_size = 360)

# Decision Tree using Train Data
dectree5 = DecisionTreeClassifier(max_depth = 2)  # create the decision tree object
dectree5.fit(x_trainnn, y_trainnn)                # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred5 = dectree5.predict(x_trainnn)
y_test_pred5 = dectree5.predict(x_testtt)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree5.score(x_trainnn, y_trainnn), "\n")

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree5.score(x_testtt, y_testtt), "\n")

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_trainnn, y_train_pred5),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_testtt, y_test_pred5), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Plot the Decision Tree
treedot5 = export_graphviz(dectree5,                            # the model
                          feature_names =x_trainnn.columns,     # the features 
                          out_file = None,                      # output file
                          filled = True,                        # node colors
                          rounded = True,                       # make pretty
                          special_characters = True)            # postscript

graphviz.Source(treedot5)
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9390909090909091
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9222222222222223

# %% [markdown]
# ---
# After obtaining Decision Tree of `CentralAir` against the 4 variables `SalePrice`, `GrLivArea`, `LotArea`, `TotalBsmtSF`, compare the Classification Accuracy (and other accuracy parameters) to determine which model is the best in order to predict `CentralAir`. What do you think?
#
# ## ANS : Predict CentralAir using All Variables
#
#     Look at level of variable in the classification tree + Gini Coefficient (lower is better)
#
# >`SalePrice`, `GrLivArea`, `LotArea`/`TotalBsmtSF`

# %%
# Import essential models and functions from sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
import graphviz

# Extract Response and Predictors
y = pd.DataFrame(houseData['CentralAir'])
x = pd.DataFrame(houseData[['SalePrice', 'GrLivArea', 'LotArea', 'TotalBsmtSF']])

# Split the Dataset into Train and Test
x_trainnn, x_testtt, y_trainnn, y_testtt = train_test_split(x, y, test_size = 360)

# Decision Tree using Train Data
dectree6 = DecisionTreeClassifier(max_depth = 3)  # create the decision tree object
dectree6.fit(x_trainnn, y_trainnn)                # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred6 = dectree6.predict(x_trainnn)
y_test_pred6 = dectree6.predict(x_testtt)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree6.score(x_trainnn, y_trainnn), "\n")

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree6.score(x_testtt, y_testtt), "\n")

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_trainnn, y_train_pred6),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_testtt, y_test_pred6), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Plot the Decision Tree
treedot6 = export_graphviz(dectree6,                            # the model
                          feature_names = x_trainnn.columns,     # the features 
                          out_file = None,                      # output file
                          filled = True,                        # node colors
                          rounded = True,                       # make pretty
                          special_characters = True)            # postscript

graphviz.Source(treedot6)
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9536363636363636
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.925

# %% [markdown]
# # <div class="alert alert-block alert-danger"> END Classification Tree
